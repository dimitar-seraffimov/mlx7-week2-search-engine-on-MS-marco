# %%
import pickle
import pandas as pd
import re

with open('dataprep/combined_vocab/tkn_vocab_to_int.pkl', 'rb') as f:
    vocab_to_int = pickle.load(f)
with open('dataprep/combined_vocab/tkn_int_to_vocab.pkl', 'rb') as f:
    int_to_vocab = pickle.load(f)

# get special token IDs
PAD_ID = vocab_to_int.get('<PAD>', 0)
UNK_ID = vocab_to_int.get('<UNK>', 1)

# %%
train_df = pd.read_parquet("dataprep/ms_marco_combined/marco_data_splits/train.parquet")
val_df   = pd.read_parquet("dataprep/ms_marco_combined/marco_data_splits/validation.parquet")
test_df  = pd.read_parquet("dataprep/ms_marco_combined/marco_data_splits/test.parquet")
print(f"Train {len(train_df)}, Val {len(val_df)}, Test {len(test_df)}")
# Out:
# Train 79004, Val 9875, Test 9876

# %%
def preprocess(text: str) -> list[str]:
    text = text.lower()
    replacements = {
        '.': ' <PERIOD> ',
        ',': ' <COMMA> ', 
        '"': ' <QUOTATION_MARK> ',
        ';': ' <SEMICOLON> ', 
        '!': ' <EXCLAMATION_MARK> ', 
        '?': ' <QUESTION_MARK> ',
        '(': ' <LEFT_PAREN> ', 
        ')': ' <RIGHT_PAREN> ', 
        '--': ' <HYPHENS> ', 
        ':': ' <COLON> '
    }
    for k, v in replacements.items():
        text = text.replace(k, v)
    words = text.split()
    return words

# %%
# tokenisation with <UNK> ratio filter
def text_to_ids(text: str, vocab_to_int: dict[str, int], max_unk_ratio: float = 0.2) -> list[int]:
    unk_id = vocab_to_int["<UNK>"]
    words = preprocess(text)
    ids = [vocab_to_int.get(word, unk_id) for word in words]
    unk_count = sum(1 for i in ids if i == unk_id)

    if len(ids) == 0 or (unk_count / len(ids)) > max_unk_ratio:
        return []
    
    return ids

# %%
for df, name in [(train_df, "train"), (val_df, "validation"), (test_df, "test")]:
    df["query_ids"] = df["query"].apply(lambda x: text_to_ids(x, vocab_to_int))
    df["pos_ids"]   = df["positive_passage"].apply(lambda x: text_to_ids(x, vocab_to_int))
    df["neg_ids"]   = df["negative_passage"].apply(lambda x: text_to_ids(x, vocab_to_int))

    df["q_len"] = df["query_ids"].str.len()
    df["p_len"] = df["pos_ids"].str.len()
    df["n_len"] = df["neg_ids"].str.len()

    print(f"{name}: avg q {df['q_len'].mean():.1f}, "
          f"p {df['p_len'].mean():.1f}, "
          f"n {df['n_len'].mean():.1f}")
# Out:
# train: avg q 6.0, p 83.2, n 80.4
# validation: avg q 6.0, p 83.1, n 80.0
# test: avg q 6.0, p 83.1, n 80.4

# %%
def display_triplets(df: pd.DataFrame, vocab: dict[int, str], n: int = 5):
    print("\n📋 Sample tokenised triplets:")
    shown = 0
    for _, row in df.iterrows():
        if not row["query_ids"] or not row["pos_ids"] or not row["neg_ids"]:
            continue  # skip dropped ones

        print("\n---")
        print(f"🔹 Query: {row['query']}")
        print(f"   Tokens: {row['query_ids']}")
        print(f"   Words:  {' '.join([int_to_vocab.get(i, '<UNK>') for i in row['query_ids']])}")

        print(f"✅ Positive: {row['positive_passage'][:100]}...")
        print(f"   Tokens: {row['pos_ids'][:10]}... ({len(row['pos_ids'])} tokens)")
        print(f"   Words:  {' '.join([int_to_vocab.get(i, '<UNK>') for i in row['pos_ids'][:10]])}...")

        print(f"❌ Negative: {row['negative_passage'][:100]}...")
        print(f"   Tokens: {row['neg_ids'][:10]}... ({len(row['neg_ids'])} tokens)")
        print(f"   Words:  {' '.join([int_to_vocab.get(i, '<UNK>') for i in row['neg_ids'][:10]])}...")
        
        shown += 1
        if shown == n:
            break

# Show 5 from each set
display_triplets(train_df, int_to_vocab)
display_triplets(val_df, int_to_vocab)
display_triplets(test_df, int_to_vocab)
# Out:
# 📋 Sample tokenised triplets:
#
# ---
# 🔹 Query: what is a landmark in colombia
#    Tokens: [71, 9, 6, 9258, 8, 5731]
#    Words:  what is a landmark in colombia
# ✅ Positive: Bogota. Colombia's capital of Bogota is in the central part of the country. The city is situated in ...
#    Tokens: [33224, 2, 97385, 963, 4, 33224, 9, 8, 1, 400]... (46 tokens)
#    Words:  bogota <PERIOD> colombia's capital of bogota is in the central...
# ❌ Negative: The second level of the food chains is called the Primary Consumer. These consume the green plants. ...
#    Tokens: [1, 284, 238, 4, 1, 153, 3452, 9, 84, 1]... (38 tokens)
#    Words:  the second level of the food chains is called the...
#
# ---
# 🔹 Query: how to prepare a field for planting pumpkins
#    Tokens: [85, 7, 2815, 6, 505, 10, 4617, 17733]
#    Words:  how to prepare a field for planting pumpkins
# ✅ Positive: 1. Prepare your soil. If you are anticipating growing in the spring, the soil can be prepared in the...
#    Tokens: [35, 2, 2815, 27, 690, 2, 41, 23, 14, 34906]... (129 tokens)
#    Words:  1 <PERIOD> prepare your soil <PERIOD> if you are anticipating...
# ❌ Negative: A. The Locarno Conference was called partly because of the failure of the Treaty of Versailles to sa...
#    Tokens: [6, 2, 1, 55808, 3121, 31, 84, 4801, 129, 4]... (101 tokens)
#    Words:  a <PERIOD> the locarno conference was called partly because of...
#
# ---
# 🔹 Query: should you lighten your hair as you get older
#    Tokens: [140, 23, 24964, 27, 668, 12, 23, 136, 977]
#    Words:  should you lighten your hair as you get older
# ✅ Positive: I don't want to be a blond. I was thinking of a change, and dying my hair a brown. Not a mousy brown...
#    Tokens: [77, 606, 319, 7, 25, 6, 27434, 2, 77, 31]... (124 tokens)
#    Words:  i don't want to be a blond <PERIOD> i was...
# ❌ Negative: HIP ABDUCTOR MUSCLES The hip abductor muscles are a group of four muscles located in the buttocks an...
#    Tokens: [2295, 34363, 452, 1, 2295, 34363, 452, 14, 6, 197]... (66 tokens)
#    Words:  hip abductor muscles the hip abductor muscles are a group...
#
# ---
# 🔹 Query: why is carbon dioxide inorganic
#    Tokens: [710, 9, 492, 1186, 4887]
#    Words:  why is carbon dioxide inorganic
# ✅ Positive: an organic compound is a compound which must contain hydrogen and carbon but carbon dioxide consists...
#    Tokens: [24, 1140, 1368, 9, 6, 1368, 36, 226, 508, 1253]... (74 tokens)
#    Words:  an organic compound is a compound which must contain hydrogen...
# ❌ Negative: The truth: Age is the most important factor affecting a woman’s chance to conceive and have a health...
#    Tokens: [1, 3482, 29, 178, 9, 1, 48, 193, 1379, 3468]... (143 tokens)
#    Words:  the truth <COLON> age is the most important factor affecting...
#
# ---
# 🔹 Query: is licorice fattening
#    Tokens: [9, 8756, 32181]
#    Words:  is licorice fattening
# ✅ Positive: No, the red part is artificial. But licorice is the real, organic part. I believe the color of organ...
#    Tokens: [114, 3, 1, 292, 128, 9, 3362, 2, 47, 8756]... (86 tokens)
#    Words:  no <COMMA> the red part is artificial <PERIOD> but licorice...
# ❌ Negative: Amount-With the Child Tax Credit, you may be able to reduce your federal income tax by up to $1,000 ...
#    Tokens: [117688, 1, 527, 407, 486, 3, 23, 52, 25, 565]... (62 tokens)
#    Words:  amount-with the child tax credit <COMMA> you may be able...
#
# 📋 Sample tokenised triplets:
#
# ---
# 🔹 Query: what do t-lymphocytes do
#    Tokens: [71, 103, 27233, 103]
#    Words:  what do t-lymphocytes do
# ✅ Positive: T cells or T lymphocytes are a type of lymphocyte (in turn, a type of white blood cell) that plays a...
#    Tokens: [491, 124, 11, 491, 4289, 14, 6, 138, 4, 14362]... (119 tokens)
#    Words:  t cells or t lymphocytes are a type of lymphocyte...
# ❌ Negative: Swordfish are elongated, round-bodied, and lose all teeth and scales by adulthood. These fish are fo...
#    Tokens: [21226, 14, 9869, 3, 119355, 3, 5, 2129, 59, 1400]... (102 tokens)
#    Words:  swordfish are elongated <COMMA> round-bodied <COMMA> and lose all teeth...
#
# ---
# 🔹 Query: how long do lobsters live
#    Tokens: [85, 142, 103, 13395, 349]
#    Words:  how long do lobsters live
# ✅ Positive: Lobsters may eat other lobsters in captivity, but this has not been observed in the wild. It takes a...
#    Tokens: [13395, 52, 600, 45, 13395, 8, 7935, 3, 47, 28]... (56 tokens)
#    Words:  lobsters may eat other lobsters in captivity <COMMA> but this...
# ❌ Negative: Latest news from Marble Falls, TX collected exclusively by city-data.com from local newspapers, TV, ...
#    Tokens: [3152, 1504, 22, 4605, 2016, 3, 6004, 2389, 4581, 21]... (120 tokens)
#    Words:  latest news from marble falls <COMMA> tx collected exclusively by...
#
# ---
# 🔹 Query: why are carbonated beverages acidic
#    Tokens: [710, 14, 14373, 4835, 4189]
#    Words:  why are carbonated beverages acidic
# ✅ Positive: Carbonic Acid. Manufacturers add carbonation to water by dissolving pressurized carbon dioxide gas i...
#    Tokens: [17673, 394, 2, 3999, 375, 27124, 7, 101, 21, 15111]... (110 tokens)
#    Words:  carbonic acid <PERIOD> manufacturers add carbonation to water by dissolving...
# ❌ Negative: A urinary tract infection (UTI) is an infection involving any part of the urinary system, including ...
#    Tokens: [6, 1946, 1141, 325, 17, 7950, 16, 9, 24, 325]... (79 tokens)
#    Words:  a urinary tract infection <LEFT_PAREN> uti <RIGHT_PAREN> is an infection...
#
# ---
# 🔹 Query: average cost to finish drywall
#    Tokens: [64, 69, 7, 2408, 5591]
#    Words:  average cost to finish drywall
# ✅ Positive: Using this type of method to determine drywall install and finish costs is pretty common in the new ...
#    Tokens: [194, 28, 138, 4, 765, 7, 910, 5591, 1257, 5]... (84 tokens)
#    Words:  using this type of method to determine drywall install and...
# ❌ Negative: Endothelial Cell Functions. Endothelial cells perform a variety of essential functions in the body. ...
#    Tokens: [12591, 175, 783, 2, 12591, 124, 1244, 6, 469, 4]... (47 tokens)
#    Words:  endothelial cell functions <PERIOD> endothelial cells perform a variety of...
#
# ---
# 🔹 Query: which of the following composers is considered a bridge composer from the classical to romantic era
#    Tokens: [36, 4, 1, 328, 8272, 9, 327, 6, 1846, 4043, 22, 1, 2203, 7, 6386, 2044]
#    Words:  which of the following composers is considered a bridge composer from the classical to romantic era
# ✅ Positive: Ludwig van Beethoven is one of the most widely recognized and admired composers in the history of We...
#    Tokens: [11124, 3415, 12375, 9, 15, 4, 1, 48, 896, 2133]... (46 tokens)
#    Words:  ludwig van beethoven is one of the most widely recognized...
# ❌ Negative: Main article: Muscle. There are three distinct types of muscles: skeletal muscles, cardiac or heart ...
#    Tokens: [288, 695, 29, 223, 2, 68, 14, 50, 1823, 190]... (79 tokens)
#    Words:  main article <COLON> muscle <PERIOD> there are three distinct types...
#
# 📋 Sample tokenised triplets:
#
# ---
# 🔹 Query: where did the people known as the acadians come from
#    Tokens: [115, 493, 1, 93, 105, 12, 1, 41038, 464, 22]
#    Words:  where did the people known as the acadians come from
# ✅ Positive: The Acadians are the descendants of French settlers who came to North America from 1604 onward. Most...
#    Tokens: [1, 41038, 14, 1, 6171, 4, 399, 6095, 94, 968]... (56 tokens)
#    Words:  the acadians are the descendants of french settlers who came...
# ❌ Negative: That's silly, in Italy they speak Italian. But not just Italian. I arrived at this topic as I was pu...
#    Tokens: [1399, 18401, 3, 8, 1412, 46, 2631, 1153, 2, 47]... (55 tokens)
#    Words:  that's silly <COMMA> in italy they speak italian <PERIOD> but...
#
# ---
# 🔹 Query: what is the function of the uterus
#    Tokens: [71, 9, 1, 342, 4, 1, 2945]
#    Words:  what is the function of the uterus
# ✅ Positive: The uterus has several important functions in the body including multiple reproductive functions suc...
#    Tokens: [1, 2945, 43, 224, 193, 783, 8, 1, 92, 165]... (56 tokens)
#    Words:  the uterus has several important functions in the body including...
# ❌ Negative: Honda released the two-door Insight, the first hybrid car to hit the mass market in the United State...
#    Tokens: [9745, 842, 1, 74756, 8140, 3, 1, 73, 4402, 561]... (91 tokens)
#    Words:  honda released the two-door insight <COMMA> the first hybrid car...
#
# ---
# 🔹 Query: where is government island
#    Tokens: [115, 9, 283, 437]
#    Words:  where is government island
# ✅ Positive: Map of Government Island. Government Island is a 1,760-acre (7 km 2) island in the Columbia River no...
#    Tokens: [1097, 4, 283, 437, 2, 283, 437, 9, 6, 35]... (103 tokens)
#    Words:  map of government island <PERIOD> government island is a 1...
# ❌ Negative: Who is a famous person from Switzerland? Some famous people who are from Switzerland include Kat Gra...
#    Tokens: [94, 9, 6, 928, 207, 22, 4350, 408, 63, 928]... (74 tokens)
#    Words:  who is a famous person from switzerland <QUESTION_MARK> some famous...
#
# ---
# 🔹 Query: what is a lira
#    Tokens: [71, 9, 6, 15916]
#    Words:  what is a lira
# ✅ Positive: lira ‎(plural lire or liras). 1  The basic unit of currency in Turkey. 2  The currency of Lebanon (a...
#    Tokens: [15916, 13284, 17, 2488, 74184, 11, 117648, 16, 2, 35]... (73 tokens)
#    Words:  lira ‎ <LEFT_PAREN> plural lire or liras <RIGHT_PAREN> <PERIOD> 1...
# ❌ Negative: In England, Wales and Scotland, you can contact the Benefits Inquiry Line on: 0800 88 22 00 or Textp...
#    Tokens: [8, 850, 3, 3146, 5, 2391, 3, 23, 26, 779]... (61 tokens)
#    Words:  in england <COMMA> wales and scotland <COMMA> you can contact...
#
# ---
# 🔹 Query: what is pipette calibration
#    Tokens: [71, 9, 52172, 19698]
#    Words:  what is pipette calibration
# ✅ Positive: PIPETTE CALIBRATION. Pipette Calibration is a fundamental part of Good Laboratory Practice (GLP) and...
#    Tokens: [52172, 19698, 2, 52172, 19698, 9, 6, 3274, 128, 4]... (37 tokens)
#    Words:  pipette calibration <PERIOD> pipette calibration is a fundamental part of...
# ❌ Negative: Multiply your daily total calorie intake by the recommended percentage of fat intake. Divide that to...
#    Tokens: [3445, 27, 631, 220, 4552, 2131, 21, 1, 1205, 1701]... (115 tokens)
#    Words:  multiply your daily total calorie intake by the recommended percentage...

# %%
train_df.to_pickle("dataprep/ms_marco_combined/tokenised/train_tokenised.pkl")
val_df.to_pickle(  "dataprep/ms_marco_combined/tokenised/validation_tokenised.pkl")
test_df.to_pickle( "dataprep/ms_marco_combined/tokenised/test_tokenised.pkl")
